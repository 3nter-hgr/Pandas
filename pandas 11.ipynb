# %% [raw]
#                          how do i change a data type of a pandas series

# %%
import pandas as pd

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# ...

# %%
drinks.beer_servings.astype('float')
# Out:
# 0        0.0
# 1       89.0
# 2       25.0
# 3      245.0
# 4      217.0
#        ...
# 188    333.0
# 189    111.0
# 190      6.0
# 191     32.0
# 192     64.0
# Name: beer_servings, Length: 193, dtype: float64

# %%
drinks['beer_servings'] = drinks['beer_servings'].astype(float)
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0                0              0
# 1        Albania           89.0              132             54
# 2        Algeria           25.0                0             14
# 3        Andorra          245.0              138            312
# 4         Angola          217.0               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0              100              3
# 189      Vietnam          111.0                2              1
# 190        Yemen            6.0                0              0
# 191       Zambia           32.0               19              4
# 192     Zimbabwe           64.0               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
#if i want to change type before actually reading the file
drinks = pd.read_csv('http://bit.ly/drinksbycountry' , dtype={'spirit_servings' : 'float'})
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0              0.0              0
# 1        Albania             89            132.0             54
# 2        Algeria             25              0.0             14
# 3        Andorra            245            138.0            312
# 4         Angola            217             57.0             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333            100.0              3
# 189      Vietnam            111              2.0              1
# 190        Yemen              6              0.0              0
# 191       Zambia             32             19.0              4
# 192     Zimbabwe             64             18.0              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
orders = pd.read_table('http://bit.ly/chiporders')
orders
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
orders.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
#item_price is an object
#we want it as a float to can mack calculations on it

# %%
orders.item_price.str.replace('$' , ' ').mean()
#it will result in an error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:1692, in _ensure_numeric(x)
#    1691 try:
# -> 1692     x = float(x)
#    1693 except (TypeError, ValueError):
#    1694     # e.g. "1+1j" or "foo"
#
# ...

# %%
#the right way
orders.item_price.str.replace('$' , ' ').astype(float).mean()
# Out:
# 7.464335785374297

# %%
orders.item_name.str.contains('Chicken').head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: item_name, dtype: bool
